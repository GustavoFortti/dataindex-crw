# %%
import os
import pandas as pd
from functions import get_all_origins, find_pattern_for_quantity, convert_to_grams, relation_qnt_preco, remove_spaces, clean_text
import re
import numpy as np

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df = pd.read_csv("/home/mage/main/dataindex-crw/data/supplement/brazil/darkness/origin_dry.csv")

# %%
df
# Out:
#          ref                       title   price  \
# 0   3fc276b6  creatine creapure darkness  137,92
# 1   4314043b           creatine darkness  143,01
# 2   fb3585d7                    dark bar  129,28
# 3   5eeb22e1                    darkwhey  134,32
# 4   161e3107                    carnibol  188,52
# 5   17dc82c9                   glutamine   86,13
# 6   644c670b                    evora pw   75,52
# 7   f67124aa                  monsterone  150,02
# 8   8d456799                  amino hard  131,74
# 9   6a1abce5                   evora rtd   55,59
# 10  9e127a42                    vasculor  116,12
# 11  bcb946af             bcaa powder fix  109,12
# 12  04ba683b               bcaa fix 4500  100,72
# 13  9f59939e     mega pack power workout  180,51
#
#                                             image_url  \
# 0   https://integralmedica.vteximg.com.br/arquivos...
# 1   https://integralmedica.vteximg.com.br/arquivos...
# 2   https://integralmedica.vteximg.com.br/arquivos...
# 3   https://integralmedica.vteximg.com.br/arquivos...
# 4   https://integralmedica.vteximg.com.br/arquivos...
# 5   https://integralmedica.vteximg.com.br/arquivos...
# 6   https://integralmedica.vteximg.com.br/arquivos...
# 7   https://integralmedica.vteximg.com.br/arquivos...
# 8   https://integralmedica.vteximg.com.br/arquivos...
# 9   https://integralmedica.vteximg.com.br/arquivos...
# 10  https://integralmedica.vteximg.com.br/arquivos...
# 11  https://integralmedica.vteximg.com.br/arquivos...
# 12  https://integralmedica.vteximg.com.br/arquivos...
# 13  https://integralmedica.vteximg.com.br/arquivos...
#
#                                           product_url    ing_date  \
# 0     https://www.darkness.com.br/creatine-creapure/p  2024-02-20
# 1     https://www.darkness.com.br/creatine-darkness/p  2024-02-20
# 2              https://www.darkness.com.br/dark-bar/p  2024-02-20
# 3              https://www.darkness.com.br/darkwhey/p  2024-02-20
# 4              https://www.darkness.com.br/carnibol/p  2024-02-20
# 5    https://www.darkness.com.br/glutamine-darkness/p  2024-02-20
# 6      https://www.darkness.com.br/pre-treino-evora/p  2024-02-20
# 7   https://www.darkness.com.br/hipercalorico-mons...  2024-02-20
# 8             https://www.darkness.com.br/aminohard/p  2024-02-20
# 9          https://www.darkness.com.br/evora-pw-rtd/p  2024-02-20
# 10             https://www.darkness.com.br/vasculor/p  2024-02-20
# 11          https://www.darkness.com.br/bcaa-powder/p  2024-02-20
# 12        https://www.darkness.com.br/bcaa-fix-4500/p  2024-02-20
# 13  https://www.darkness.com.br/mega-pack-power-wo...  2024-02-20
#
#                           name     brand  price_numeric  quantity  price_qnt  \
# 0   creatine creapure darkness  darkness         137.92       NaN        NaN
# 1            creatine darkness  darkness         143.01       NaN        NaN
# 2                     dark bar  darkness         129.28       NaN        NaN
# 3                     darkwhey  darkness         134.32       NaN        NaN
# 4                     carnibol  darkness         188.52       NaN        NaN
# 5                    glutamine  darkness          86.13       NaN        NaN
# 6                     évora pw  darkness          75.52       NaN        NaN
# 7                   monsterone  darkness         150.02       NaN        NaN
# 8                   amino hard  darkness         131.74       NaN        NaN
# 9                    évora rtd  darkness          55.59       NaN        NaN
# 10                    vasculor  darkness         116.12       NaN        NaN
# 11             bcaa powder fix  darkness         109.12       NaN        NaN
# 12               bcaa fix 4500  darkness         100.72       NaN        NaN
# 13     mega pack power workout  darkness         180.51       NaN        NaN
#
#                                                spec_5  \
# 0                  creatina creatine creatin creapure
# 1                  creatina creatine creatin creapure
# 2                                  barrinha barra bar
# 3                                                 NaN
# 4                                                 NaN
# 5             glutamin glutamine glutamina lglutamina
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                           bcaa bca
# 12                                           bcaa bca
# 13  pretreino workout pretrein preworkout pre workout
#
#                                           spec_4  \
# 0             creatina creatine creatin creapure
# 1                                            NaN
# 2   protein proteina proteica barrinha barra bar
# 3                                            NaN
# 4                                            NaN
# 5                                     aminoacido
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9               beta alanina betaalanina alanina
# 10                                           NaN
# 11                                           NaN
# 12                                           NaN
# 13                                           NaN
#
#                                                spec_3  \
# 0                                                 NaN
# 1                  creatina creatine creatin creapure
# 2                                                 NaN
# 3                                                 NaN
# 4   protein proteina proteica colageno colagen ble...
# 5                                                 NaN
# 6                                                 NaN
# 7   whey protein proteina proteica creatina creati...
# 8   protein proteina proteica glutamin glutamine g...
# 9      taurina cafein cafe cafeina coffe caffe coffee
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  beta alanina betaalanina alanina arginin argin...
#
#                                                spec_2  spec_1
# 0                  creatina creatine creatin creapure     NaN
# 1   creatina creatine creatin creapure protein pro...     NaN
# 2   vit vitamina vitamin protein proteina proteica...     NaN
# 3                           protein proteina proteica     NaN
# 4                           protein proteina proteica     NaN
# 5             glutamin glutamine glutamina lglutamina     NaN
# 6                                                 NaN     NaN
# 7   creatina creatine creatin creapure protein pro...     NaN
# 8                                                 NaN     NaN
# 9   beta alanina betaalanina alanina cafein cafe c...     NaN
# 10                                                NaN     NaN
# 11                                                NaN     NaN
# 12                                                NaN     NaN
# 13                                           magnesio     NaN
